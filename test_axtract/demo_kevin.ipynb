# %%
from axiomatic import Axiomatic
from axiomatic import axtract
import numercial_values_manager

ax_client = Axiomatic(timeout=1000, api_key="2d702671-4b31-4174-a88e-087a02e3c29a")
data_files = ax_client.requirements.data_files.retrieve()
variables_dict = data_files['results']['variables']

# %%
user_choice =  axtract.interactive_table(variable_dict = variables_dict)
# Out:
# Dropdown(description='Select Option:', options=('Select a template', 'IMAGING TELESCOPE', 'IMAGING TELESCOPE t…
# VBox()
# Output()
# HBox(children=(Button(button_style='success', description='Submit', style=ButtonStyle()), Button(button_style=…
# /opt/anaconda3/envs/axiomatic/lib/python3.13/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(FloatText).__init__(placeholder='Value').
# object.__init__() takes exactly one argument (the instance to initialize)
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(

# %%
parameter_names = list(user_choice['values'].keys())
path = 'zurbuchen2007.pdf'
processed_values = numercial_values_manager.get_numerical_values(ax_client, path, parameter_names)

# %%
user_choice =  axtract.interactive_table(variable_dict = variables_dict)
# Out:
# Dropdown(description='Select Option:', options=('Select a template', 'IMAGING TELESCOPE', 'IMAGING TELESCOPE t…
# VBox()
# Output()
# HBox(children=(Button(button_style='success', description='Submit', style=ButtonStyle()), Button(button_style=…

# %%
requirements = axtract.requirements_from_table(user_choice, variables_dict)

# %%
output = ax_client.requirements.check(request = requirements)

#let's print the results
axtract.display_full_results(output['results'],requirements=requirements)
# Out:
# <div style="background-color:#1e1e1e; padding:20px; border-radius:10px; margin:20px 0; border:1px solid #3e3e3e;"><h2 style="font-family:Arial; color:#e0e0e0; margin-bottom:15px">Equation Validation Analysis</h2><p style="font-family:Arial; font-size:16px; color:#e0e0e0"><b>Total equations analyzed:</b> 5<br><span style="color:#4caf50">✅ Matching equations: 2</span><br><span style="color:#ff5252">❌ Non-matching equations: 3</span></p></div>
# <div style="background-color:#2d1f1f; padding:20px; border-radius:10px; margin:20px 0; border:1px solid #4a2f2f;"><h3 style="color:#ff5252; font-family:Arial">⚠️ Equations Not Satisfied</h3>
# $\displaystyle \text{GSD}_p =  (h_{alt}*p_p)/f$
# <div style="font-family:monospace; margin-left:20px; margin-bottom:20px; background-color:#2a2a2a; color:#e0e0e0; padding:15px; border-radius:5px; border-left:4px solid #ff5252">Left side  = 0.6<br>Right side = 1212.35<br>Absolute difference = 1211.75<br>Relative difference = 99.95%</div>
# $\displaystyle \text{Swath} =  2*h_{alt}*tan(\text{HFOV})$
# <div style="font-family:monospace; margin-left:20px; margin-bottom:20px; background-color:#2a2a2a; color:#e0e0e0; padding:15px; border-radius:5px; border-left:4px solid #ff5252">Left side  = 0<br>Right side = 2044.76<br>Absolute difference = 2044.76<br>Relative difference = 100.00%</div>
# $\displaystyle \text{GSD}_{ms} =  (h_{alt}*p_{ms})/f$
# <div style="font-family:monospace; margin-left:20px; margin-bottom:20px; background-color:#2a2a2a; color:#e0e0e0; padding:15px; border-radius:5px; border-left:4px solid #ff5252">Left side  = 0.9<br>Right side = 0.0018012<br>Absolute difference = 0.898199<br>Relative difference = 49866.56%</div>
# </div>
# <div style="background-color:#1f2d1f; padding:20px; border-radius:10px; margin:20px 0; border:1px solid #2f4a2f;"><h3 style="color:#4caf50; font-family:Arial">✅ Satisfied Equations</h3>
# $\displaystyle r_p =  2*\text{GSD}_p$
# <div style="font-family:monospace; margin-left:20px; margin-bottom:20px; background-color:#2a2a2a; color:#e0e0e0; padding:15px; border-radius:5px; border-left:4px solid #4caf50">Value = 1.2</div>
# $\displaystyle r_{ms} =  2*\text{GSD}_{ms}$
# <div style="font-family:monospace; margin-left:20px; margin-bottom:20px; background-color:#2a2a2a; color:#e0e0e0; padding:15px; border-radius:5px; border-left:4px solid #4caf50">Value = 1.8</div>
# </div>
# <div style="background-color:#1e1e1e; padding:20px; border-radius:10px; margin:20px 0; border:1px solid #3e3e3e;"><h3 style="color:#e0e0e0; font-family:Arial">🔍 Equation Relationship Analysis</h3><p style="font-family:Arial; color:#e0e0e0">The following graph shows how variables are connected through equations:</p></div>
